# %% [markdown]
# # 🚀 Hands-On Computer Vision — Colab 快速启动
#
# 运行此 Cell 来安装所有必要的依赖并克隆项目代码。
#
# > 之后，你可以打开任意章节的 Notebook 开始学习！

# %%
# 安装必要的依赖
# !pip install opencv-contrib-python numpy matplotlib Pillow scipy scikit-learn -q

# %%
# 验证安装
import cv2
import numpy as np
import matplotlib.pyplot as plt

print(f"OpenCV version: {cv2.__version__}")
print(f"NumPy version: {np.__version__}")
print("✅ 所有依赖安装成功！")

# %% [markdown]
# ## 📚 开始学习
#
# 点击下面的链接打开你想学的章节：
#
# **第一部分：图像处理基础**
# - [数字图像的获取和表示](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/图像处理基础/数字图像的获取和表示/编程实践.ipynb)
# - [颜色空间的转换](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/图像处理基础/颜色空间的转换/编程实践.ipynb)
# - [基于直方图统计的处理](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/图像处理基础/基于直方图统计的处理/编程实践.ipynb)
# - [图像滤波](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/图像处理基础/图像滤波/编程实践.ipynb)
# - [特征提取](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/图像处理基础/特征提取/编程实践.ipynb)
# - [几何变换](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/图像处理基础/几何变换/编程实践.ipynb)
#
# **第二部分：最优化算法与立体视觉重建**
# - [图像拼接模型](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/最优化算法与立体视觉重建/图像拼接模型/编程实践.ipynb)
# - [相机参数标定](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/最优化算法与立体视觉重建/相机参数标定/编程实践.ipynb)
# - [立体视觉点云重建](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/最优化算法与立体视觉重建/立体视觉点云重建/编程实践.ipynb)
#
# **第三部分：EXTRA 进阶章节**
# - [卷积](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/EXTRA/卷积/编程实践_补充.ipynb)
# - [模板匹配](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/EXTRA/模板匹配/编程实践_补充.ipynb)
# - [图像分割](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/EXTRA/图像分割/编程实践_补充.ipynb)
# - [图像分类](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/EXTRA/图像分类/编程实践_补充.ipynb)
# - [语义分割](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/EXTRA/语义分割/编程实践_补充.ipynb)
# - [目标检测](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/EXTRA/目标检测/编程实践_补充.ipynb)
# - [实例分割](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/EXTRA/实例分割/编程实践_补充.ipynb)
# - [人体姿态估计](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/EXTRA/人体姿态估计/编程实践_补充.ipynb)
# - [动作识别](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/EXTRA/动作识别/编程实践_补充.ipynb)
# - [光流和运动场](https://colab.research.google.com/github/your-github-username/Hands-On-Computer-Vision/blob/main/EXTRA/光流和运动场/编程实践_补充.ipynb)
